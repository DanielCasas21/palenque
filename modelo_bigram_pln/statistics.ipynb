# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Traemos ese archivo y lo imprimimos
df = pd.read_csv('/content/drive/MyDrive/NLP/NLP Assignment 2/entity_matching_pal_bigram.csv')
df
# Out:
#    output  matches  accuracy_%
# 0      10        7       70.00
# 1     100       66       66.00
# 2    1000      651       65.10
# 3   10000     6319       63.19
# 4  100000    63140       63.14

# %%
# Traemos ese archivo y lo imprimimos
df2 = pd.read_csv('/content/drive/MyDrive/NLP/NLP Assignment 2/novelty_pal_bigram.csv')
df2
# Out:
#    output  matches  accuracy_%
# 0      10        0       0.000
# 1     100        1       1.000
# 2    1000       10       1.000
# 3   10000       86       0.860
# 4  100000      837       0.837
